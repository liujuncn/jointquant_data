# %%
far = analyze_factor(factor=MlFactor,
                     start_date='2012-01-01',
                     end_date='2019-07-01',
                     weight_method='mktcap',
                     universe='000300.XSHG',
                     industry='jq_l1',
                     quantiles=10,
                     periods=(5, 10)
                    )

# %%
far.plot_returns_table(demeaned=False, group_adjust=False)
# Out:
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.092      0.083
# beta                                             -1.022     -1.037
# Mean Period Wise Return Top Quantile (bps)        6.646      5.996
# Mean Period Wise Return Bottom Quantile (bps)    -0.042      0.842
# Mean Period Wise Spread (bps)                     7.157      5.782

# %%
far.plot_quantile_returns_bar(by_group=False, demeaned=False, group_adjust=False)

# %%
far.plot_cumulative_returns_by_quantile(period=(3, 5), demeaned=False, group_adjust=False)

# %%
far.plot_information_table(group_adjust=False, method='rank')
# Out:
# IC 分析
#              period_5  period_10
# IC Mean         0.045      0.053
# IC Std.         0.160      0.160
# IR              0.279      0.334
# t-stat(IC)     11.883     14.236
# p-value(IC)     0.000      0.000
# IC Skew        -0.073     -0.157
# IC Kurtosis    -0.200     -0.260

# %%
far.plot_ic_by_group(group_adjust=False, method='rank')

# %%
far.plot_ic_hist(group_adjust=False, method='rank')

# %%
far.plot_monthly_ic_heatmap(group_adjust=False)

# %%
far.plot_turnover_table()
# Out:
# 换手率分析
#                             period_10  period_5
# Quantile 1 Mean Turnover        0.344     0.250
# Quantile 2 Mean Turnover        0.636     0.520
# Quantile 3 Mean Turnover        0.711     0.603
# Quantile 4 Mean Turnover        0.743     0.644
# Quantile 5 Mean Turnover        0.746     0.653
# Quantile 6 Mean Turnover        0.750     0.657
# Quantile 7 Mean Turnover        0.736     0.647
# Quantile 8 Mean Turnover        0.715     0.628
# Quantile 9 Mean Turnover        0.657     0.566
# Quantile 10 Mean Turnover       0.424     0.329
#                                   period_5  period_10
# Mean Factor Rank Autocorrelation     0.915      0.852

# %%
far.plot_quantile_average_cumulative_return(periods_before=5, periods_after=30, 
                                            by_quantile=False, std_bar=False, demeaned=False, group_adjust=False)

# %%
far.plot_returns_table(demeaned=True, group_adjust=True)
# Out:
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.096      0.085
# beta                                             -0.041     -0.043
# Mean Period Wise Return Top Quantile (bps)        2.264      1.735
# Mean Period Wise Return Bottom Quantile (bps)    -3.747     -2.924
# Mean Period Wise Spread (bps)                     6.106      4.787

# %%
far.plot_quantile_returns_bar(by_group=False, demeaned=True, group_adjust=True)

# %%
far.plot_cumulative_returns_by_quantile(period=(3, 5), demeaned=True, group_adjust=True)

# %%
far.plot_information_table(group_adjust=True, method='rank')
# Out:
# IC 分析
#              period_5  period_10
# IC Mean         0.042      0.050
# IC Std.         0.149      0.149
# IR              0.283      0.334
# t-stat(IC)     12.077     14.251
# p-value(IC)     0.000      0.000
# IC Skew        -0.084     -0.151
# IC Kurtosis    -0.068     -0.284

# %%
far.plot_ic_by_group(group_adjust=True, method='rank')

# %%
far.plot_quantile_average_cumulative_return(periods_before=5, periods_after=30, 
                                            by_quantile=False, std_bar=False, demeaned=True, group_adjust=True)
