# %%
far = analyze_factor(factor=MlFactor,
                     start_date='2015-01-01',
                     end_date='2019-07-01',
                     weight_method='avg',
                     universe='000906.XSHG',
                     industry='jq_l1',
                     quantiles=10,
                     periods=(5, 10)
                    )

# %%
far.plot_returns_table(demeaned=False, group_adjust=False)
# Out:
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.175      0.160
# beta                                             -0.715     -0.706
# Mean Period Wise Return Top Quantile (bps)        9.262      9.015
# Mean Period Wise Return Bottom Quantile (bps)    -7.158     -6.244
# Mean Period Wise Spread (bps)                    16.480     15.253

# %%
far.plot_quantile_returns_bar(by_group=False, demeaned=False, group_adjust=False)

# %%
far.plot_cumulative_returns_by_quantile(period=(3, 5), demeaned=False, group_adjust=False)

# %%
far.plot_information_table(group_adjust=False, method='rank')
# Out:
# IC 分析
#              period_5  period_10
# IC Mean         0.075      0.090
# IC Std.         0.149      0.151
# IR              0.506      0.596
# t-stat(IC)     16.736     19.723
# p-value(IC)     0.000      0.000
# IC Skew        -0.173     -0.144
# IC Kurtosis    -0.127     -0.411

# %%
far.plot_ic_by_group(group_adjust=False, method='rank')

# %%
far.plot_ic_hist(group_adjust=False, method='rank')

# %%
far.plot_monthly_ic_heatmap(group_adjust=False)

# %%
far.plot_turnover_table()
# Out:
# 换手率分析
#                             period_10  period_5
# Quantile 1 Mean Turnover        0.385     0.270
# Quantile 2 Mean Turnover        0.675     0.546
# Quantile 3 Mean Turnover        0.748     0.639
# Quantile 4 Mean Turnover        0.770     0.677
# Quantile 5 Mean Turnover        0.778     0.689
# Quantile 6 Mean Turnover        0.778     0.684
# Quantile 7 Mean Turnover        0.763     0.666
# Quantile 8 Mean Turnover        0.726     0.620
# Quantile 9 Mean Turnover        0.646     0.527
# Quantile 10 Mean Turnover       0.380     0.274
#                                   period_5  period_10
# Mean Factor Rank Autocorrelation     0.902      0.821

# %%
far.plot_quantile_average_cumulative_return(periods_before=5, periods_after=30, 
                                            by_quantile=False, std_bar=False, demeaned=False, group_adjust=False)

# %%
far.plot_returns_table(demeaned=True, group_adjust=True)
# Out:
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.177      0.158
# beta                                              0.021      0.032
# Mean Period Wise Return Top Quantile (bps)        6.191      5.832
# Mean Period Wise Return Bottom Quantile (bps)    -9.637     -8.875
# Mean Period Wise Spread (bps)                    15.929     14.782

# %%
far.plot_quantile_returns_bar(by_group=False, demeaned=True, group_adjust=True)

# %%
far.plot_cumulative_returns_by_quantile(period=(3, 5), demeaned=True, group_adjust=True)

# %%
far.plot_information_table(group_adjust=True, method='rank')
# Out:
# IC 分析
#              period_5  period_10
# IC Mean         0.073      0.087
# IC Std.         0.145      0.148
# IR              0.500      0.589
# t-stat(IC)     16.537     19.489
# p-value(IC)     0.000      0.000
# IC Skew        -0.196     -0.166
# IC Kurtosis    -0.138     -0.427

# %%
far.plot_ic_by_group(group_adjust=True, method='rank')

# %%
far.plot_quantile_average_cumulative_return(periods_before=5, periods_after=30, 
                                            by_quantile=False, std_bar=False, demeaned=True, group_adjust=True)
