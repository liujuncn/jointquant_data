# %%
far = analyze_factor(factor=MlFactor,
                     start_date='2012-01-01',
                     end_date='2019-07-01',
                     weight_method='mktcap',
                     universe='000300.XSHG',
                     industry='jq_l1',
                     quantiles=10,
                     periods=(5, 10)
                    )

# %%
far.plot_returns_table(demeaned=False, group_adjust=False)
# Out:
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.119      0.105
# beta                                             -1.026     -1.047
# Mean Period Wise Return Top Quantile (bps)        6.656      6.384
# Mean Period Wise Return Bottom Quantile (bps)    -0.658      0.234
# Mean Period Wise Spread (bps)                     7.841      7.026

# %%
far.plot_quantile_returns_bar(by_group=False, demeaned=False, group_adjust=False)

# %%
far.plot_cumulative_returns_by_quantile(period=(3, 5), demeaned=False, group_adjust=False)

# %%
far.plot_information_table(group_adjust=False, method='rank')
# Out:
# IC 分析
#              period_5  period_10
# IC Mean         0.049      0.058
# IC Std.         0.161      0.161
# IR              0.305      0.361
# t-stat(IC)     13.015     15.404
# p-value(IC)     0.000      0.000
# IC Skew         0.020     -0.047
# IC Kurtosis    -0.260     -0.251

# %%
far.plot_ic_by_group(group_adjust=False, method='rank')

# %%
far.plot_ic_hist(group_adjust=False, method='rank')

# %%
far.plot_monthly_ic_heatmap(group_adjust=False)

# %%
far.plot_turnover_table()
# Out:
# 换手率分析
#                             period_10  period_5
# Quantile 1 Mean Turnover        0.395     0.274
# Quantile 2 Mean Turnover        0.676     0.554
# Quantile 3 Mean Turnover        0.763     0.667
# Quantile 4 Mean Turnover        0.807     0.734
# Quantile 5 Mean Turnover        0.823     0.764
# Quantile 6 Mean Turnover        0.833     0.784
# Quantile 7 Mean Turnover        0.831     0.789
# Quantile 8 Mean Turnover        0.819     0.775
# Quantile 9 Mean Turnover        0.781     0.728
# Quantile 10 Mean Turnover       0.613     0.510
#                                   period_5  period_10
# Mean Factor Rank Autocorrelation      0.82      0.717

# %%
far.plot_quantile_average_cumulative_return(periods_before=5, periods_after=30, 
                                            by_quantile=False, std_bar=False, demeaned=False, group_adjust=False)

# %%
far.plot_returns_table(demeaned=True, group_adjust=True)
# Out:
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.115      0.103
# beta                                             -0.039     -0.047
# Mean Period Wise Return Top Quantile (bps)        1.942      2.004
# Mean Period Wise Return Bottom Quantile (bps)    -4.692     -3.688
# Mean Period Wise Spread (bps)                     6.802      5.894

# %%
far.plot_quantile_returns_bar(by_group=False, demeaned=True, group_adjust=True)

# %%
far.plot_cumulative_returns_by_quantile(period=(3, 5), demeaned=True, group_adjust=True)

# %%
far.plot_information_table(group_adjust=True, method='rank')
# Out:
# IC 分析
#              period_5  period_10
# IC Mean         0.048      0.057
# IC Std.         0.149      0.149
# IR              0.322      0.380
# t-stat(IC)     13.755     16.230
# p-value(IC)     0.000      0.000
# IC Skew         0.030     -0.022
# IC Kurtosis    -0.138     -0.168

# %%
far.plot_ic_by_group(group_adjust=True, method='rank')

# %%
far.plot_quantile_average_cumulative_return(periods_before=5, periods_after=30, 
                                            by_quantile=False, std_bar=False, demeaned=True, group_adjust=True)
