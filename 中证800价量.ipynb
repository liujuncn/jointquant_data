# %%
far = analyze_factor(factor=MlFactor,
                     start_date='2015-01-01',
                     end_date='2019-07-01',
                     weight_method='mktcap',
                     universe='000906.XSHG',
                     industry='jq_l1',
                     quantiles=10,
                     periods=(5, 10)
                    )

# %%
far.plot_returns_table(demeaned=False, group_adjust=False)
# Out:
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.192      0.183
# beta                                             -0.676     -0.680
# Mean Period Wise Return Top Quantile (bps)        9.542      9.416
# Mean Period Wise Return Bottom Quantile (bps)    -2.414     -1.758
# Mean Period Wise Spread (bps)                    11.395     10.596

# %%
far.plot_quantile_returns_bar(by_group=False, demeaned=False, group_adjust=False)

# %%
far.plot_cumulative_returns_by_quantile(period=(3, 5), demeaned=False, group_adjust=False)

# %%
far.plot_information_table(group_adjust=False, method='rank')
# Out:
# IC 分析
#              period_5  period_10
# IC Mean         0.068      0.081
# IC Std.         0.153      0.156
# IR              0.445      0.516
# t-stat(IC)     14.708     17.054
# p-value(IC)     0.000      0.000
# IC Skew        -0.071     -0.025
# IC Kurtosis    -0.193     -0.434

# %%
far.plot_ic_by_group(group_adjust=False, method='rank')

# %%
far.plot_ic_hist(group_adjust=False, method='rank')

# %%
far.plot_monthly_ic_heatmap(group_adjust=False)

# %%
far.plot_turnover_table()
# Out:
# 换手率分析
#                             period_10  period_5
# Quantile 1 Mean Turnover        0.512     0.351
# Quantile 2 Mean Turnover        0.717     0.603
# Quantile 3 Mean Turnover        0.770     0.668
# Quantile 4 Mean Turnover        0.791     0.693
# Quantile 5 Mean Turnover        0.799     0.700
# Quantile 6 Mean Turnover        0.798     0.698
# Quantile 7 Mean Turnover        0.788     0.684
# Quantile 8 Mean Turnover        0.761     0.657
# Quantile 9 Mean Turnover        0.708     0.583
# Quantile 10 Mean Turnover       0.491     0.333
#                                   period_5  period_10
# Mean Factor Rank Autocorrelation     0.875      0.753

# %%
far.plot_quantile_average_cumulative_return(periods_before=5, periods_after=30, 
                                            by_quantile=False, std_bar=False, demeaned=False, group_adjust=False)

# %%
far.plot_returns_table(demeaned=True, group_adjust=True)
# Out:
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.154      0.140
# beta                                              0.047      0.061
# Mean Period Wise Return Top Quantile (bps)        5.009      4.806
# Mean Period Wise Return Bottom Quantile (bps)    -6.383     -5.708
# Mean Period Wise Spread (bps)                    11.435     10.519

# %%
far.plot_quantile_returns_bar(by_group=False, demeaned=True, group_adjust=True)

# %%
far.plot_cumulative_returns_by_quantile(period=(3, 5), demeaned=True, group_adjust=True)

# %%
far.plot_information_table(group_adjust=True, method='rank')
# Out:
# IC 分析
#              period_5  period_10
# IC Mean         0.063      0.075
# IC Std.         0.146      0.150
# IR              0.432      0.498
# t-stat(IC)     14.297     16.477
# p-value(IC)     0.000      0.000
# IC Skew        -0.102     -0.071
# IC Kurtosis    -0.219     -0.450

# %%
far.plot_ic_by_group(group_adjust=True, method='rank')

# %%
far.plot_quantile_average_cumulative_return(periods_before=5, periods_after=30, 
                                            by_quantile=False, std_bar=False, demeaned=True, group_adjust=True)
