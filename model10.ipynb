# %%
far = analyze_factor(factor=MlFactor,
                     start_date='2012-01-01',
                     end_date='2019-07-01',
                     weight_method='avg',
                     universe='000300.XSHG',
                     industry='jq_l1',
                     quantiles=10,
                     periods=(5, 10)
                    )

# %%
far.create_full_tear_sheet(demeaned=True,
                           group_adjust=True,
                           by_group=True,
                           turnover_periods=None,
                           avgretplot=(5, 60),
                           std_bar=True
                          )
# Out:
# 分位数统计
#                       min       max    ...      count    count %
# factor_quantile                        ...
# 1               -0.016034 -0.003540    ...      53193  10.156240
# 2               -0.005717 -0.002330    ...      52293   9.984401
# 3               -0.004084 -0.001564    ...      52087   9.945069
# 4               -0.002977 -0.000857    ...      52283   9.982492
# 5               -0.001783 -0.000246    ...      52489  10.021824
# 6               -0.001221  0.000284    ...      51914   9.912038
# 7               -0.000720  0.000704    ...      52071   9.942014
# 8               -0.000172  0.001334    ...      52299   9.985546
# 9                0.000455  0.001838    ...      52081   9.943923
# 10               0.000959  0.005704    ...      53037  10.126454
#
# [10 rows x 6 columns]
# -------------------------
#
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.088      0.077
# beta                                             -0.010     -0.009
# Mean Period Wise Return Top Quantile (bps)        2.591      2.240
# Mean Period Wise Return Bottom Quantile (bps)    -4.991     -4.621
# Mean Period Wise Spread (bps)                     7.720      6.977
# -------------------------
#
# IC 分析
#              period_5  period_10
# IC Mean         0.042      0.049
# IC Std.         0.161      0.161
# IR              0.264      0.308
# t-stat(IC)     11.248     13.132
# p-value(IC)     0.000      0.000
# IC Skew        -0.084     -0.158
# IC Kurtosis    -0.187     -0.271
# -------------------------
#
# 换手率分析
#                             period_10  period_5
# Quantile 1 Mean Turnover        0.349     0.243
# Quantile 2 Mean Turnover        0.634     0.502
# Quantile 3 Mean Turnover        0.711     0.591
# Quantile 4 Mean Turnover        0.747     0.638
# Quantile 5 Mean Turnover        0.751     0.646
# Quantile 6 Mean Turnover        0.754     0.648
# Quantile 7 Mean Turnover        0.734     0.618
# Quantile 8 Mean Turnover        0.698     0.576
# Quantile 9 Mean Turnover        0.612     0.484
# Quantile 10 Mean Turnover       0.340     0.246
#                                   period_5  period_10
# Mean Factor Rank Autocorrelation     0.926       0.86
# -------------------------

# %%
far.plot_ic_hist(group_adjust=False, method='rank')
