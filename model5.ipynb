# %%
far = analyze_factor(factor=MlFactor,
                     start_date='2012-01-01',
                     end_date='2019-07-01',
                     weight_method='mktcap',
                     universe='000300.XSHG',
                     industry='jq_l1',
                     quantiles=10,
                     periods=(5, 10)
                    )

# %%
far.create_full_tear_sheet(demeaned=True,
                           group_adjust=True,
                           by_group=True,
                           turnover_periods=None,
                           avgretplot=(5, 60),
                           std_bar=True
                          )
# Out:
# 分位数统计
#                       min       max    ...      count    count %
# factor_quantile                        ...
# 1               -0.010267 -0.002191    ...      53193  10.156240
# 2               -0.003712 -0.001609    ...      52293   9.984401
# 3               -0.002649 -0.001114    ...      52087   9.945069
# 4               -0.001898 -0.000689    ...      52283   9.982492
# 5               -0.001302 -0.000350    ...      52489  10.021824
# 6               -0.001013 -0.000070    ...      51914   9.912038
# 7               -0.000644  0.000197    ...      52071   9.942014
# 8               -0.000333  0.000525    ...      52299   9.985546
# 9               -0.000027  0.000841    ...      52081   9.943923
# 10               0.000326  0.005282    ...      53037  10.126454
#
# [10 rows x 6 columns]
# -------------------------
#
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.097      0.086
# beta                                             -0.031     -0.034
# Mean Period Wise Return Top Quantile (bps)        1.468      1.005
# Mean Period Wise Return Bottom Quantile (bps)    -4.036     -3.694
# Mean Period Wise Spread (bps)                     5.598      4.789
# -------------------------
#
# IC 分析
#              period_5  period_10
# IC Mean         0.045      0.052
# IC Std.         0.163      0.163
# IR              0.280      0.321
# t-stat(IC)     11.930     13.681
# p-value(IC)     0.000      0.000
# IC Skew        -0.049     -0.119
# IC Kurtosis    -0.175     -0.278
# -------------------------
#
# 换手率分析
#                             period_10  period_5
# Quantile 1 Mean Turnover        0.378     0.264
# Quantile 2 Mean Turnover        0.672     0.546
# Quantile 3 Mean Turnover        0.746     0.635
# Quantile 4 Mean Turnover        0.774     0.681
# Quantile 5 Mean Turnover        0.780     0.690
# Quantile 6 Mean Turnover        0.777     0.687
# Quantile 7 Mean Turnover        0.763     0.671
# Quantile 8 Mean Turnover        0.729     0.627
# Quantile 9 Mean Turnover        0.645     0.530
# Quantile 10 Mean Turnover       0.368     0.268
#                                   period_5  period_10
# Mean Factor Rank Autocorrelation     0.902       0.82
# -------------------------

# %%
far.plot_ic_hist(group_adjust=False, method='rank')

# %%
far = analyze_factor(factor=MlFactor,
                     start_date='2012-01-01',
                     end_date='2019-07-01',
                     weight_method='avg',
                     universe='000300.XSHG',
                     industry='jq_l1',
                     quantiles=10,
                     periods=(5, 10)
                    )

# %%
far.create_full_tear_sheet(demeaned=True,
                           group_adjust=True,
                           by_group=True,
                           turnover_periods=None,
                           avgretplot=(5, 60),
                           std_bar=True
                          )
# Out:
# 分位数统计
#                       min       max    ...      count    count %
# factor_quantile                        ...
# 1               -0.010267 -0.002191    ...      53193  10.156240
# 2               -0.003712 -0.001609    ...      52293   9.984401
# 3               -0.002649 -0.001114    ...      52087   9.945069
# 4               -0.001898 -0.000689    ...      52283   9.982492
# 5               -0.001302 -0.000350    ...      52489  10.021824
# 6               -0.001013 -0.000070    ...      51914   9.912038
# 7               -0.000644  0.000197    ...      52071   9.942014
# 8               -0.000333  0.000525    ...      52299   9.985546
# 9               -0.000027  0.000841    ...      52081   9.943923
# 10               0.000326  0.005282    ...      53037  10.126454
#
# [10 rows x 6 columns]
# -------------------------
#
# 收益分析
#                                                period_5  period_10
# Ann. alpha                                        0.094      0.083
# beta                                             -0.010     -0.010
# Mean Period Wise Return Top Quantile (bps)        3.060      2.725
# Mean Period Wise Return Bottom Quantile (bps)    -4.950     -4.741
# Mean Period Wise Spread (bps)                     8.142      7.576
# -------------------------
